# %%
import numpy as np

from triqs.gf import *
from triqs.gf.meshes import MeshDLRImFreq, MeshDLRImTime

from triqs.gf import *
from triqs.operators import *
from triqs.operators.util.hamiltonians import h_int_slater
from triqs.operators.util import *
from triqs.operators.util.hamiltonians import *

from triqs.atom_diag import *

import numpy as np
from itertools import product
import matplotlib.pylab as plt
import time
from triqs.plot.mpl_interface import oplot,plt

from gwsolver import GWSolver
from gwsolvercpp import GWSolverCPP

def number_of_particles(g_w):
    return g_w.total_density().real

def number_of_particles_DLR(g_w):
    g_dlr = make_gf_dlr(g_w)
    rho = g_dlr.density()
    N = 0
    for name, g in g_w:
        N += np.sum(np.diag(rho[name].data)).real
    return N

def dyson(g0_w, mu):
    g_w = g0_w.copy()
    for name, g in g0_w:
        g_w[name] = (g0_w[name].inverse() - mu).inverse()
    return g_w

def fix_particle_number(g, N, eps = 1e-3):
    g_w = g.copy()
    step = 1.0

    particle_number = number_of_particles(g_w)

    while abs(particle_number - N) > eps:
        # print(particle_number)
        if particle_number - N > 0:
            g_w = dyson(g_w, step)
        elif particle_number - N < 0:
            g_w = dyson(g_w, -step)
        step = 0.99 * step
        particle_number = number_of_particles(g_w)

    return g_w

def number_of_particles_from_ad(H, fundamental_operators, number_operator, beta, mu):
    Hmu = H + mu * number_operator
    atomic_diagonal = AtomDiagComplex(Hmu, fundamental_operators)
    density_matrix = atomic_density_matrix(atomic_diagonal, beta)
    filling = trace_rho_op(density_matrix, number_operator, atomic_diagonal)
    return filling.real, atomic_diagonal

def fix_atomic_diag(H, fundamental_operators, target_occupation, number_operator, beta, mu = None, eps = 1e-6):
    if mu is None:
        mu = 0

    step = 1.0

    occupation, atomic_diagonal = number_of_particles_from_ad(H, fundamental_operators, number_operator, beta, mu)

    previous_direction = None
    iterator = 0
    while abs(occupation - target_occupation) > eps:
        if occupation - target_occupation > 0:
            if previous_direction == 'decrement':
                step /= 2
            previous_direction = 'increment'
            mu += step
        if occupation - target_occupation < 0:
            if previous_direction == 'increment':
                step /= 2
            previous_direction = 'decrement'
            mu -= step
        occupation, atomic_diagonal = number_of_particles_from_ad(H, fundamental_operators, number_operator, beta, mu)
        iterator += 1
        # print(f"ED Iteration {iterator}: mu = {mu}, N = {occupation}", end='\r')
    return atomic_diagonal, mu

def exact_diag(tij, V, occupation = None, beta = 100, nw = 1 * 1024):
    spin_names = ['up', 'dn']
    orbital_names = range(len(tij))

    if occupation is None:
        occupation = len(tij)

    fundamental_operators = [(spin_name, orbital_name) for spin_name, orbital_name in product(spin_names, orbital_names)]

    N = 0
    for i in orbital_names:
        N += n('up', i) + n('dn', i)

    H = h_int_slater(spin_names, len(orbital_names), V, off_diag = True, complex = True)
        
    for spin, i, j in product(spin_names, orbital_names, orbital_names):
        H += tij[i, j] * c_dag(spin, i) * c(spin, j)
        
    atomic_diagonal, mu = fix_atomic_diag(H, fundamental_operators, occupation, N, beta)

    gf_struct = [('dn', len(orbital_names)),
                ('up', len(orbital_names))]

    G_w = atomic_g_iw(atomic_diagonal, beta, gf_struct, nw)
    return G_w

def generate_g0_w(tij, mesh, spin_names = ['up', 'dn']):
    g_inv = Gf(mesh = mesh, target_shape = np.shape(tij))
    g_inv << iOmega_n - tij.transpose()
    g = g_inv.inverse()
    return BlockGf(block_list = [g] * 2, name_list = spin_names, make_copies = False)

def coulomb_matrix(orbitals, U, non_local = True):
    Vij = np.zeros([orbitals] * 2)
    for i in range(orbitals):
        for j in range(orbitals):
            Vij[i, j] = round(U / (abs(i - j) + 1), 2)
    

    if non_local:
        return Vij

    return np.diag(Vij.diagonal())

def coulomb_tensor(orbitals, U, non_local = True):
    Vij = coulomb_matrix(orbitals, U, non_local)
    Vijkl = np.zeros([orbitals] * 4)
    for i in range(orbitals):
        for j in range(orbitals):
            Vijkl[i, j, i, j] = Vij[i, j]
    return Vijkl


orbitals = 100

t = 1.0

tij = np.zeros([orbitals] * 2)
for i in range(orbitals - 1):
    tij[i, i + 1] = -t
    tij[i + 1, i] = -t

U = 0.1
Vij = coulomb_matrix(orbitals, U)
# Vijkl = coulomb_tensor(orbitals, U)

beta = 200

mesh = MeshDLRImFreq(beta = beta, statistic = 'Fermion',  w_max = 1.0, eps = 1e-12, symmetrize = True)
G_w = generate_g0_w(tij, mesh)


hartree_flag = True
fock_flag = True

start = time.perf_counter()
gw = GWSolver(G_w.copy(), Vij, self_interactions = True, hartree_flag = hartree_flag, fock_flag = fock_flag, N_fix = False)
print("Python time : {}".format(round(time.perf_counter() - start, 3)))

start = time.perf_counter()
gwCPP = GWSolverCPP(G_w.copy(), Vij, self_interactions = True, hartree_flag = hartree_flag, fock_flag = fock_flag , N_fix = False)
print("CPP time : {}".format(round(time.perf_counter() - start, 3)))

g_w = gwCPP.g_w
g_w2 = gwCPP.g_w

print(np.allclose(g_w['up'].data, g_w2['up'].data))
print(np.allclose(g_w['dn'].data, g_w2['dn'].data))
# ED = exact_diag(tij, Vijkl, orbitals, beta)
# Out:
# Python time : 1.446
# Iteration 1/1
#
# WARNING: Maximum iterations reached
# CPP time : 0.496
# True
# True

# %%
# fig, axs = plt.subplots(orbitals, orbitals, figsize = (7 * orbitals, 7 * orbitals), facecolor = 'black')
# spin = 'dn'

# for i in range(orbitals):
#     for j in range(orbitals):
#         axs[i, j].set_facecolor('black')
#         axs[i, j].xaxis.label.set_color('white')
#         axs[i, j].tick_params(axis = 'x', colors = 'white')
#         axs[i, j].yaxis.label.set_color('white')
#         axs[i, j].tick_params(axis = 'y', colors = 'white')
#         axs[i, j].set_xlim(-5, 5)

#         axs[i, j].scatter([w.imag for w in g_w.mesh.values()], g_w[spin].data[:, i, j].real, color = 'red', zorder = 1)
#         axs[i, j].scatter([w.imag for w in g_w.mesh.values()], g_w[spin].data[:, i, j].imag, color = 'red', zorder = 1)

#         axs[i, j].scatter([w.imag for w in g_w.mesh.values()], g_w[spin].data[:, i, j].real, color = 'blue', zorder = 1)
#         axs[i, j].scatter([w.imag for w in g_w.mesh.values()], g_w[spin].data[:, i, j].imag, color = 'blue', zorder = 1)

#         axs[i, j].plot([w.imag for w in ED.mesh.values()], ED[spin].data[:, i, j].real, color = 'white', zorder = 0)
#         axs[i, j].plot([w.imag for w in ED.mesh.values()], ED[spin].data[:, i, j].imag, color = 'white', zorder = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_39540/150164629.py in <module>
# ----> 1 fig, axs = plt.subplots(orbitals, orbitals, figsize = (7 * orbitals, 7 * orbitals), facecolor = 'black')
#       2 spin = 'dn'
#       3
#       4 for i in range(orbitals):
#       5     for j in range(orbitals):
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1433     """
#    1434     fig = figure(**fig_kw)
# -> 1435     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1436                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1437                        gridspec_kw=gridspec_kw)
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#     895             gridspec_kw = {}
#     896         gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 897         axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     898                           subplot_kw=subplot_kw)
#     899         return axs
#
# /usr/lib/python3/dist-packages/matplotlib/gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     305                 subplot_kw["sharex"] = shared_with[sharex]
#     306                 subplot_kw["sharey"] = shared_with[sharey]
# --> 307                 axarr[row, col] = figure.add_subplot(
#     308                     self[row, col], **subplot_kw)
#     309
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     770             projection_class, pkw = self._process_projection_requirements(
#     771                 *args, **kwargs)
# --> 772             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773             key = (projection_class, pkw)
#     774         return self._add_axes_internal(ax, key)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      32         """
#      33         # _axes_class is set in the subplot_class_factory
# ---> 34         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35         # This will also update the axes position.
#      36         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# /usr/lib/python3/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     630
#     631         self._rasterization_zorder = None
# --> 632         self.cla()
#     633
#     634         # funcs used to format x and y - fall back on major formatters
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in cla(self)
#    1247         self.containers = []
#    1248
# -> 1249         self.grid(False)  # Disable grid on init to use rcParameter
#    1250         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1251                   axis=mpl.rcParams['axes.grid.axis'])
#
# /usr/lib/python3/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     297                 f"for the old name will be dropped %(removal)s.")
#     298             kwargs[new] = kwargs.pop(old)
# --> 299         return func(*args, **kwargs)
#     300
#     301     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in grid(self, visible, which, axis, **kwargs)
#    3224         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3225         if axis in ['x', 'both']:
# -> 3226             self.xaxis.grid(visible, which=which, **kwargs)
#    3227         if axis in ['y', 'both']:
#    3228             self.yaxis.grid(visible, which=which, **kwargs)
#
# /usr/lib/python3/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     297                 f"for the old name will be dropped %(removal)s.")
#     298             kwargs[new] = kwargs.pop(old)
# --> 299         return func(*args, **kwargs)
#     300
#     301     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in grid(self, visible, which, **kwargs)
#    1432             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1433                                 if visible is None else visible)
# -> 1434             self.set_tick_params(which='major', **gridkw)
#    1435         self.stale = True
#    1436
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     872                 self._major_tick_kw.update(kwtrans)
#     873                 for tick in self.majorTicks:
# --> 874                     tick._apply_params(**kwtrans)
#     875             if which in ['minor', 'both']:
#     876                 self._minor_tick_kw.update(kwtrans)
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in _apply_params(self, **kw)
#     388                     if k in ['labelsize', 'labelcolor']}
#     389         self.label1.set(**label_kw)
# --> 390         self.label2.set(**label_kw)
#     391
#     392         grid_kw = {k[5:]: v for k, v in kw.items()
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     114             return
#     115
# --> 116         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117         cls.set.__name__ = "set"
#     118         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in set(self, **kwargs)
#    1162         # module.
#    1163         kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164         return self.update(kwargs)
#    1165
#    1166     @contextlib.contextmanager
#
# /usr/lib/python3/dist-packages/matplotlib/text.py in update(self, kwargs)
#     170         # Update bbox last, as it depends on font properties.
#     171         bbox = kwargs.pop("bbox", sentinel)
# --> 172         super().update(kwargs)
#     173         if bbox is not sentinel:
#     174             self.set_bbox(bbox)
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in update(self, props)
#    1053         """
#    1054         ret = []
# -> 1055         with cbook._setattr_cm(self, eventson=False):
#    1056             for k, v in props.items():
#    1057                 # Allow attributes we want to be able to update through
#
# /usr/lib/python3.10/contextlib.py in helper(*args, **kwds)
#     279     @wraps(func)
#     280     def helper(*args, **kwds):
# --> 281         return _GeneratorContextManager(func, args, kwds)
#     282     return helper
#     283
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/lib/python3/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2287                 # CL works.  "tight" also needs a draw to get the right
#    2288                 # locations:
# -> 2289                 renderer = _get_renderer(
#    2290                     self.figure,
#    2291                     functools.partial(
#
# /usr/lib/python3/dist-packages/matplotlib/backend_bases.py in _get_renderer(figure, print_method)
#    1542                 figure.canvas._get_output_canvas(None, fmt), f"print_{fmt}")
#    1543         try:
# -> 1544             print_method(io.BytesIO())
#    1545         except Done as exc:
#    1546             renderer, = figure._cachedRenderer, = exc.args
#
# /usr/lib/python3/dist-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# /usr/lib/python3/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     429     def draw(self):
#     430         # docstring inherited
# --> 431         self.renderer = self.get_renderer(cleared=True)
#     432         # Acquire a lock on the shared font cache.
#     433         with RendererAgg.lock, \
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     445                           and getattr(self, "_lastKey", None) == key)
#     446         if not reuse_renderer:
# --> 447             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     448             self._lastKey = key
#     449         elif cleared:
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      91         self.width = width
#      92         self.height = height
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 100800x100800 pixels is too large. It must be less than 2^16 in each direction.
